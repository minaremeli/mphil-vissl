# %%
import vissl
import tensorboard
import apex
import torch

# %%
# %cd ..
# Out:
# /home/mr892/vissl

# %%
# !python3 tools/run_distributed_engines.py \
    hydra.verbose=true \
    config=my_configs/quick_swav.yaml
# Out:
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# ####### overrides: ['hydra.verbose=true', 'config=my_configs/quick_swav.yaml']
# INFO 2022-04-14 19:37:14,628 distributed_launcher.py: 183: Spawning process for node_id: 0, local_rank: 0, dist_rank: 0, dist_run_id: localhost:46675
# INFO 2022-04-14 19:37:14,628 train.py:  94: Env set for rank: 0, dist_rank: 0
# INFO 2022-04-14 19:37:14,628 env.py:  50: CLICOLOR:	1
# INFO 2022-04-14 19:37:14,628 env.py:  50: CONDA_EXE:	/opt/conda/bin/conda
# INFO 2022-04-14 19:37:14,628 env.py:  50: CONDA_PYTHON_EXE:	/opt/conda/bin/python
# INFO 2022-04-14 19:37:14,628 env.py:  50: CONDA_SHLVL:	0
# INFO 2022-04-14 19:37:14,628 env.py:  50: DBUS_SESSION_BUS_ADDRESS:	unix:path=/run/user/4808/bus
# INFO 2022-04-14 19:37:14,628 env.py:  50: GIT_PAGER:	cat
# INFO 2022-04-14 19:37:14,628 env.py:  50: HOME:	/home/mr892
# ...

# %%
# !ls data/CIFAR-100-dataset/train/
# Out:
# apple	       castle	    fox		mushroom      road	    tank
# aquarium_fish  caterpillar  girl	oak_tree      rocket	    telephone
# baby	       cattle	    hamster	orange	      rose	    television
# bear	       chair	    house	orchid	      sea	    tiger
# beaver	       chimpanzee   kangaroo	otter	      seal	    tractor
# bed	       clock	    keyboard	palm_tree     shark	    train
# bee	       cloud	    lamp	pear	      shrew	    trout
# beetle	       cockroach    lawn_mower	pickup_truck  skunk	    tulip
# bicycle        couch	    leopard	pine_tree     skyscraper    turtle
# bottle	       crab	    lion	plain	      snail	    wardrobe
# bowl	       crocodile    lizard	plate	      snake	    whale
# boy	       cup	    lobster	poppy	      spider	    willow_tree
# bridge	       dinosaur     man		porcupine     squirrel	    wolf
# bus	       dolphin	    maple_tree	possum	      streetcar     woman
# butterfly      elephant     motorcycle	rabbit	      sunflower     worm
# ...
